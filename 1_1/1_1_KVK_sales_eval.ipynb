# %% [markdown]
# # API KULCS (sajátot adj meg!)

# %%
open_ai_api_key = "sajat_google_api_kulcsod"

# %% [markdown]
# # Google Sheets tábla beolvasása

# %%
import requests
import csv
from io import StringIO

sheet_id = "14HAoq-Ie3RSYfSl6h5bxqTL-fKhTp9r7vxTn6lcBChM"
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv"

response = requests.get(url)
response.encoding = "utf-8"

reader = csv.reader(StringIO(response.text))
rows = list(reader)

for row in rows:
    print(row)
# Out:
# ['lead_id', 'ceg_nev', 'iparag', 'bejovo_uzenet', 'tavalyi_arbevetel', 'tavalyi_profit']
# ['L001', 'A1 Kft.', 'ételrendelés / e-commerce', 'Szia! Napi 80-100 rendelésünk van, de a Google Ads költésünk mostanában nagyon elszaladt. Szeretnénk valakit, aki átnézi a kampányokat és javasol egy gyors optimalizálási tervet. Ha működik, havi együttműködésben gondolkodunk.', '185000000', '24000000']
# ['L002', 'A2 EV', 'lakberendezési webshop', 'Szia, most inditottuk a webshopot és van napi kb 5-10 látogató. érdekelne SEO meg hirdetés is, de még nincs fix büdzsé. Első körben csak szeretnénk látni nagyjából mibe kerülne egy ilyen együttműködés.', 'ez az első évem', '']
# ['L003', 'A3 Kft.', 'fitness terem', 'Két új edzőtermünk nyílik szeptemberben, és szeretnénk addigra leadeket gyűjteni próbaedzésekre. Meta és Google kampányban gondolkodunk, a nyitás miatt elég sürgős lenne. Kérlek hívjatok fel még ma vagy holnap.', '94000000', '8700000']
# ['L004', 'A4 Kft.', 'építőipari szolgáltatás', 'Évek óta ajánlásokból dolgozunk, de most szeretnénk online is ügyfeleket szerezni. A weboldalunk régi, hirdetésünk nincs. Nem tudjuk, SEO-val vagy Google Ads-szel érdemes-e kezdeni, ehhez kérnénk tanácsot.', '320000000', '41000000']
# ['L005', 'A5 EV', 'online oktatás', 'Van egy futó kurzusunk, de a landing oldal konverziója gyenge. Körülbelül 4000 látogatóból csak 28 vásárló lett az utóbbi kampányban. Olyan partnert keresünk, aki CRO-ban és kampányoptimalizálásban is tud segíteni.', '42000000', '6200000']
# ['L006', 'A6 Kft.', 'egészségügy / magánklinika', 'Fogászati implant kampányt szeretnénk indítani Budapesten. Már dolgoztunk ügynökséggel, de kevés volt a minőségi érdeklődő. Havi 1,5-2 millió forint hirdetési keretben gondolkodunk, és fontos lenne a pontos mérés.', '780000000', '96000000']
# ['L007', 'A7 EV', 'kisállat webshop', 'Helló! Több insta meg tiktok követőt szeretnénk, meg néha poszt ötleteket is. Hirdetésre most olyan havi 80 ezer lenne maximum, de egy kisebb teszt kampányt kipróbálnánk.', '28000000', '3100000']
# ['L008', 'A8 Kft.', 'jogi szolgáltatás', 'B2B ügyfeleket szeretnénk elérni adatvédelmi és szerződéses tanácsadásra. Nem tömeges lead kell, hanem kevés, de jó minőségű megkeresés. LinkedIn és tartalommarketing érdekelne minket.', '210000000', '39000000']
# ['L009', 'A9 Kft.', 'autóalkatrész webshop', 'A Google Shopping kampányunk teljesen szétesett a termékfeed hibák miatt. A bevételünk múlt hónapban 35%-ot esett. Sürgős segítség kellene feed javításban, mérésben és kampány újrastruktúrálásban.', '640000000', '52000000']
# ['L010', 'A10 Kft.', 'helyi szolgáltatás', 'facebook oldal kéne meg posztok kutyakozmetika van kis helyi üzlet nem akarunk nagy hirdetés csak legyen valami normális olda meg néha poszt ha lehet olcson köszi', '18000000', '1200000']

# %% [markdown]
# # Egyetlen sornyi adat kiértékelése OpenAI API hívással

# %%
import requests

row = rows[5]

prompt = f"""Értékeld a leadet 0-100 pont között.
A jó lead jellemzői:
* konkrét digitális marketing problémát ír le
* van üzleti célja: több lead, több webshop rendelés, jobb ROAS, jobb mérés, automatizált riport
* van sürgősség vagy döntési helyzet
* van pénzügyi kapacitásra utaló jel: árbevétel/profit/büdzsé/növekedés
* nem csak "érdeklődöm", hanem konkrét következő lépést kér
* digitális marketing ügynökség számára releváns szolgáltatást keres
* akkor is lehet jó lead, ha EV vagy kisebb cég, amennyiben konkrét és fizetőképes igénye van
A gyenge lead jellemzői:
* nincs konkrét probléma
* nincs büdzsé vagy nagyon kicsi a cég
* csak általános érdeklődés
* nem releváns szolgáltatást kér
* nem döntéshozó vagy nem derül ki a szándék
* a pénzügyi adatok hiányosak vagy bizonytalanok, és az üzenetből sem derül ki erős üzleti potenciál
* az üzenet nagyon igénytelen, zavaros vagy nehezen érthető, és emiatt nem látszik tisztán a valódi igény
Fontos:
* a cégnév anonimizált, abból ne következtess valódi cégméretre vagy minőségre
* az üzenet minősége fontos szempont legyen: a rossz helyesírás rossz leadre utal
* ha az árbevétel vagy profit mező üres, "nem tudom" vagy "ez az első évem", akkor a bejövő üzenet alapján próbáld megítélni az üzleti potenciált

Lead adatok:
- Iparág: {row[2]}
- Üzenet: {row[3]}
- Tavalyi árbevétel: {row[4]}
- Tavalyi profit: {row[5]}

Válaszolj csak így: PONTSZÁM: [szám] | INDOKLÁS: [1-2 mondat]"""

response = requests.post(
    "https://api.openai.com/v1/chat/completions",
    headers={"Authorization": "Bearer " + open_ai_api_key},
    json={
        "model": "gpt-4o-mini",
        "messages": [{"role": "user", "content": prompt}]
    }
)

print(response.json()["choices"][0]["message"]["content"])
# Out:
# PONTSZÁM: 85 | INDOKLÁS: A lead konkrét digitális marketing problémát azonosít (gyenge konverzió), üzleti célt határoz meg (több vásárló), és jelzi a pénzügyi kapacitást a tavalyi árbevétel és profit alapján. A következő lépést is keresik, ami erősíti a lead potenciálját.

# %% [markdown]
# # Minden összefűzve, automatikus kiértékelése minden sornak a táblában

# %%
import requests
import csv
from io import StringIO

# --- STEP 1: Get leads from Google Sheet ---
sheet_id = "14HAoq-Ie3RSYfSl6h5bxqTL-fKhTp9r7vxTn6lcBChM"
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv"

response = requests.get(url)
response.encoding = "utf-8"

reader = csv.reader(StringIO(response.text))
rows = list(reader)

# --- STEP 2: Evaluate each lead ---
for row in rows[1:]:   # skip header
    prompt = f"""Értékeld a leadet 0-100 pont között.
A jó lead jellemzői:
* konkrét digitális marketing problémát ír le
* van üzleti célja: több lead, több webshop rendelés, jobb ROAS, jobb mérés, automatizált riport
* van sürgősség vagy döntési helyzet
* van pénzügyi kapacitásra utaló jel: árbevétel/profit/büdzsé/növekedés
* nem csak "érdeklődöm", hanem konkrét következő lépést kér
* digitális marketing ügynökség számára releváns szolgáltatást keres
* akkor is lehet jó lead, ha EV vagy kisebb cég, amennyiben konkrét és fizetőképes igénye van
A gyenge lead jellemzői:
* nincs konkrét probléma
* nincs büdzsé vagy nagyon kicsi a cég
* csak általános érdeklődés
* nem releváns szolgáltatást kér
* nem döntéshozó vagy nem derül ki a szándék
* a pénzügyi adatok hiányosak vagy bizonytalanok, és az üzenetből sem derül ki erős üzleti potenciál
* az üzenet nagyon igénytelen, zavaros vagy nehezen érthető, és emiatt nem látszik tisztán a valódi igény
Fontos:
* a cégnév anonimizált, abból ne következtess valódi cégméretre vagy minőségre
* az üzenet minősége fontos szempont legyen: a rossz helyesírás rossz leadre utal
* ha az árbevétel vagy profit mező üres, "nem tudom" vagy "ez az első évem", akkor a bejövő üzenet alapján próbáld megítélni az üzleti potenciált

Lead adatok:
- Iparág: {row[2]}
- Üzenet: {row[3]}
- Tavalyi árbevétel: {row[4]}
- Tavalyi profit: {row[5]}

Válaszolj csak így: PONTSZÁM: [szám] | INDOKLÁS: [1-2 mondat]"""

    response = requests.post(
        "https://api.openai.com/v1/chat/completions",
        headers={"Authorization": "Bearer " + open_ai_api_key},
        json={
            "model": "gpt-4o-mini",
            "messages": [{"role": "user", "content": prompt}]
        }
    )

    evaluation = response.json()["choices"][0]["message"]["content"]
    print(f"{row[0]}: {evaluation}")
# Out:
# L001: PONTSZÁM: 88 | INDOKLÁS: A lead konkrét digitális marketing problémát ír le, és a célja egy gyors optimalizálási terv készítése a Google Ads kampányok javítása érdekében. Az üzleti cél és a pénzügyi adatok is erősítik az üzleti potenciált, ráadásul a jövőbeli együttműködés lehetősége is szerepel az üzenetben.
# L002: PONTSZÁM: 40 | INDOKLÁS: A lead érdeklődése releváns digitális marketing szolgáltatások iránt, de hiányzik a fix büdzsé és a konkrét pénzügyi adatok, így nincs világos üzleti potenciál. Emellett az üzenet általános érdeklődésen alapul, nem pedig konkrét döntési helyzeten.
# L003: PONTSZÁM: 85 | INDOKLÁS: A lead konkrét digitális marketing problémát fogalmaz meg, sürgős üzleti céllal rendelkezik (leadek gyűjtése a nyitás előtt), és jól definiált pénzügyi háttérrel bír. A következő lépések kérésével is megmutatja a határozott szándékot. Azonban a kampányok pontos részleteinek megadása hiányzik.
# L004: PONTSZÁM: 85 | INDOKLÁS: A lead konkrét digitális marketing problémát jelöl meg, mivel online ügyfélszerzési igénye van a régi weboldal és hirdetések hiánya miatt. A jelentős árbevétel és profit azt is jelzi, hogy van pénzügyi kapacitásuk a beruházásra. Az, hogy tanácsot kérnek SEO vagy Google Ads terén, jelzi a sürgősséget és a döntési helyzetet, de a következő lépésre való konkrét kérdés hiánya érdemelne egy kis levonást.
# L005: PONTSZÁM: 85 | INDOKLÁS: A lead jól körülhatárolt digitális marketing problémát fogalmaz meg, konkrét célja van a konverzió javítása érdekében, és sürgősséget is tükröz, mivel partner keresése folyamatban van. A jelentős árbevétel és profit alapján erős üzleti potenciál látható, a lead releváns szolgáltatást keres.
# L006: PONTSZÁM: 90 | INDOKLÁS: A lead konkrét digitális marketing problémát fogalmaz meg (minőségi érdeklődők hiánya), van üzleti célja (fogászati implant kampány), és sürgősséget is mutat. A hirdetési keret és a jelentős árbevétel, valamint profit is alátámasztja a pénzügyi kapacitást, amely releváns digitális marketing szolgáltatások iránti érdeklődést jelez.
# L007: PONTSZÁM: 65 | INDOKLÁS: A lead konkrét digitális marketing problémát fogalmaz meg (követőszerzés és poszt ötletek), és van üzleti célja is a hirdetési büdzsé említésével. Az árbevétel és profit adatai alapján van pénzügyi kapacitásuk, de a sürgősség és a döntési helyzet nem egyértelmű, és a hirdetési költségkeretük viszonylag alacsony.
# L008: PONTSZÁM: 85 | INDOKLÁS: A lead konkrét digitális marketing problémát fogalmaz meg, amely üzleti célokat tűz ki, mint a B2B ügyfelek elérése és a jó minőségű megkeresések szerzése. Az árbevétel és profit adatai is jelentős pénzügyi kapacitást mutatnak, de a sürgősség vagy döntési helyzet kevésbé világos.
# L009: PONTSZÁM: 95 | INDOKLÁS: A lead konkrét digitális marketing problémát jelez, sürgős segítséget kér, és van erős üzleti célja, mivel a bevétel csökkenése komoly kihívást jelent. A jelentős árbevétel és profit további nyomatékot ad a pénzügyi kapacitásának, így a lead potenciálja magas.
# L010: PONTSZÁM: 45 | INDOKLÁS: Az üzenet nem tartalmaz konkrét digitális marketing problémát, és a kérés inkább általános érdeklődésre utal, mivel nem világos, hogy milyen célokat szeretne elérni a cég. Bár van pénzügyi adat, a megfogalmazás igénytelen és nem utal sürgősségre vagy konkrét lépésekre.
